# %% [markdown]
# KHIZAR MEHMOOD
# 01-134212-074

# %%
import cv2

# %%
img = cv2.imread("image.jpg")

# %%
img2 = cv2.imread(r"images\jpeg-home.jpg")

# %%
img3 = cv2.imread("images\jpeg-home.jpg")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# <>:1: SyntaxWarning: invalid escape sequence '\j'
# C:\Users\MY PC\AppData\Local\Temp\ipykernel_16164\1618878986.py:1: SyntaxWarning: invalid escape sequence '\j'
#   img3 = cv2.imread("images\jpeg-home.jpg")

# %%
height, width, channels = img.shape
print(f"eight: {height}, Width: {width}, Channels: {channels}")
# Out:
# eight: 400, Width: 800, Channels: 3

# %%
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
b,g,r = cv2.split(img)
cv2.imshow("Model Red Image", r)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("Model Green Image", g)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("Model Blue Image", b)
cv2.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("image.jpg")
imgplot = plt.imshow(img)
plt.show()

# %%
from PIL import Image
img = Image.open("image.jpg")
img.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset from seaborn
iris = sns.load_dataset('iris')

# Display the first few rows of the dataset
print("Iris Dataset:")
print(iris.head())

# Display basic information about the dataset
print("\nDataset Information:")
print(iris.info())

# Display the shape of the dataset
print("\nShape of the dataset:", iris.shape)

# Visualize the dataset
sns.pairplot(iris, hue='species', markers=["o", "s", "D"])
plt.title("Iris Dataset Pairplot")
plt.show()
# Out:
# Iris Dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Shape of the dataset: (150, 5)

# %%
#Task6

import cv2
import numpy as np

img = cv2.imread("image.jpg")

blue,green,red = cv2.split(img)

gray = 0.299*red + 0.587*green + 0.114*blue

gray = gray.astype(np.uint8)

# Save the grayscale image
cv2.imwrite('grayscale_image.jpg', gray)

gray_image = cv2.merge([gray, gray, gray])

cv2.imshow("image", gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
